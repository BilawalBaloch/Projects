# %% [markdown]
# <a href="https://colab.research.google.com/github/BilawalBaloch/Projects/blob/main/test_match_datacleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Test Match data cleaning and modeling**
#
# **HERE is the list what we did**
#
# 1.   Importing important libr & excel file
# 2.   Looking for Null values sum , accordig to the columns
# 3.  Renaming NO to Not Out as given on website
# 4. Fillin For null vales
# 5. looking for duplicate and removing them
# 6. Spliytting country and players name
# 7. giving new names on 1 and 0 basies
# 8. Making two new columns out of one cloumn
# 9. Correcting data type

# %% [markdown]
# # *Importing important libr & excel file*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_excel('/content/test.match.data.xlsx')
data.head(7)
# Out:
#               Player       Span  Mat  Inns    NO  Runs    HS    Ave     BF  \
# 0   DG Bradman (AUS)  1928-1948   52    80  10.0  6996   334  99.94  9800+
# 1     AC Voges (AUS)  2015-2016   20    31   7.0  1485  269*  61.87   2667
# 2    RG Pollock (SA)  1963-1970   23    41   4.0  2256   274  60.97  1707+
# 3    GA Headley (WI)  1930-1954   22    40   4.0  2190  270*  60.83   416+
# 4  H Sutcliffe (ENG)  1924-1935   54    84   9.0  4555   194  60.73  6558+
# 5     HC Brook (ENG)  2022-2024   15    24   1.0  1378   186  59.91   1520
# 6    E Paynter (ENG)  1931-1939   20    31   5.0  1540   243  59.23  1288+
#
#       SR  100  50  0   4s  6s
# 0  58.60   29  13  7  626   6
# 1  55.68    5   4  2  186   5
# 2  54.48    7  11  1  246  11
# 3  56.00   10   5  2  104   1
# 4  34.59   16  23  2  202   6
# 5  90.65    5   8  1  164  25
# 6  45.88    4   7  3  125   4

# %%
data.tail(4)
# Out:
#                Player       Span  Mat  Inns    NO  Runs   HS    Ave     BF  \
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13.0  9265  277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4.0  2122  266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5.0  2748  232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6.0  1296  127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 58  59.67   27  38  11  1165  24
# 59  44.77    7   6   1   119   0
# 60  60.02    6  13   4   241   5
# 61  25.59    1  10   2    53   0

# %% [markdown]
# # **Looking for Null values sum , accordig to the columns**
#
# ---

# %%
data.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        1
# Runs      0
# HS        0
# Ave       0
# BF        2
# SR        2
# 100       0
# 50        0
# 0         0
# 4s        0
# 6s        0
# dtype: int64

# %% [markdown]
# **Renaming NO to Not Out as given on website**

# %%
data.rename(columns={'NO':'Not_Out'}, inplace=True)

# %%
data.rename(columns={'HS':'highest_score'}, inplace=True)

# %%
data.rename(columns={'BF':'Ball_Faced'}, inplace=True)

# %%
data.rename(columns={'SR':'Strike_Rate'}, inplace=True)

# %%
data.rename(columns={'Span':'year_period'}, inplace=True)

# %%
data
# Out:
#                Player year_period  Mat  Inns  Not_Out  Runs highest_score  \
# 0    DG Bradman (AUS)   1928-1948   52    80     10.0  6996           334
# 1      AC Voges (AUS)   2015-2016   20    31      7.0  1485          269*
# 2     RG Pollock (SA)   1963-1970   23    41      4.0  2256           274
# 3     GA Headley (WI)   1930-1954   22    40      4.0  2190          270*
# 4   H Sutcliffe (ENG)   1924-1935   54    84      9.0  4555           194
# ..                ...         ...  ...   ...      ...   ...           ...
# 57   KD Walters (AUS)   1965-1981   74   125     14.0  5357           250
# 58  GC Smith (ICC/SA)   2002-2014  117   205     13.0  9265           277
# 59  WH Ponsford (AUS)   1924-1934   29    48      4.0  2122           266
# 60    SJ McCabe (AUS)   1930-1938   39    62      5.0  2748           232
# 61   DR Jardine (ENG)   1928-1934   22    33      6.0  1296           127
#
#       Ave Ball_Faced  Strike_Rate  100  50   0    4s  6s
# ...

# %%
data.isnull().sum()
# Out:
# Player           0
# year_period      0
# Mat              0
# Inns             0
# Not_Out          1
# Runs             0
# highest_score    0
# Ave              0
# Ball_Faced       2
# Strike_Rate      2
# 100              0
# 50               0
# 0                0
# 4s               0
# 6s               0
# dtype: int64

# %%
data.isnull().any()
# Out:
# Player           False
# year_period      False
# Mat              False
# Inns             False
# Not_Out           True
# Runs             False
# highest_score    False
# Ave              False
# Ball_Faced        True
# Strike_Rate       True
# 100              False
# 50               False
# 0                False
# 4s               False
# 6s               False
# dtype: bool

# %%
data_dropna = data.dropna(how='all')
print(data_dropna)
# Out:
#                Player year_period  Mat  Inns  Not_Out  Runs highest_score  \
# 0    DG Bradman (AUS)   1928-1948   52    80     10.0  6996           334
# 1      AC Voges (AUS)   2015-2016   20    31      7.0  1485          269*
# 2     RG Pollock (SA)   1963-1970   23    41      4.0  2256           274
# 3     GA Headley (WI)   1930-1954   22    40      4.0  2190          270*
# 4   H Sutcliffe (ENG)   1924-1935   54    84      9.0  4555           194
# ..                ...         ...  ...   ...      ...   ...           ...
# 57   KD Walters (AUS)   1965-1981   74   125     14.0  5357           250
# 58  GC Smith (ICC/SA)   2002-2014  117   205     13.0  9265           277
# 59  WH Ponsford (AUS)   1924-1934   29    48      4.0  2122           266
# 60    SJ McCabe (AUS)   1930-1938   39    62      5.0  2748           232
# 61   DR Jardine (ENG)   1928-1934   22    33      6.0  1296           127
#
#       Ave Ball_Faced  Strike_Rate  100  50   0    4s  6s
# ...

# %% [markdown]
# # **Fillin For null vales**

# %%
data['Ball_Faced'] = data['Ball_Faced'].fillna(method='ffill')
data['Strike_Rate'] = data['Strike_Rate'].fillna(method='bfill')
data['Not_Out'] = data['Not_Out'].fillna(method='bfill')
# Out:
# <ipython-input-491-3041b8f594ae>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Ball_Faced'] = data['Ball_Faced'].fillna(method='ffill')
# <ipython-input-491-3041b8f594ae>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Strike_Rate'] = data['Strike_Rate'].fillna(method='bfill')
# <ipython-input-491-3041b8f594ae>:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Not_Out'] = data['Not_Out'].fillna(method='bfill')

# %%
data.isnull().sum()
# Out:
# Player           0
# year_period      0
# Mat              0
# Inns             0
# Not_Out          0
# Runs             0
# highest_score    0
# Ave              0
# Ball_Faced       0
# Strike_Rate      0
# 100              0
# 50               0
# 0                0
# 4s               0
# 6s               0
# dtype: int64

# %%
#data['Ball_Faced'] = data['Ball_Faced'].fillna(data['Ball_Faced'])==1

# %%
#data['Strike_Rate'] = data['Strike_Rate'].fillna(data['Strike_Rate'])==2

# %%
#data['Not_Out'] = data['Not_Out'].fillna(data['Not_Out'])==3

# %% [markdown]
# # **looking for duplicate and removing them**

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates()
# Out:
#                Player year_period  Mat  Inns  Not_Out  Runs highest_score  \
# 0    DG Bradman (AUS)   1928-1948   52    80     10.0  6996           334
# 1      AC Voges (AUS)   2015-2016   20    31      7.0  1485          269*
# 2     RG Pollock (SA)   1963-1970   23    41      4.0  2256           274
# 3     GA Headley (WI)   1930-1954   22    40      4.0  2190          270*
# 4   H Sutcliffe (ENG)   1924-1935   54    84      9.0  4555           194
# ..                ...         ...  ...   ...      ...   ...           ...
# 57   KD Walters (AUS)   1965-1981   74   125     14.0  5357           250
# 58  GC Smith (ICC/SA)   2002-2014  117   205     13.0  9265           277
# 59  WH Ponsford (AUS)   1924-1934   29    48      4.0  2122           266
# 60    SJ McCabe (AUS)   1930-1938   39    62      5.0  2748           232
# 61   DR Jardine (ENG)   1928-1934   22    33      6.0  1296           127
#
#       Ave Ball_Faced  Strike_Rate  100  50   0    4s  6s
# ...

# %% [markdown]
# # **Spliytting country and players name**

# %%
data['Player'].str.split(pat = '\(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [AC Voges , AUS)]
# 2       [RG Pollock , SA)]
# 3       [GA Headley , WI)]
# 4     [H Sutcliffe , ENG)]
#               ...
# 57     [KD Walters , AUS)]
# 58    [GC Smith , ICC/SA)]
# 59    [WH Ponsford , AUS)]
# 60      [SJ McCabe , AUS)]
# 61     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %% [markdown]
# **giving new names on 1 and 0 basies**

# %%
data['country'] = data['Player'].str.split(pat = '\(').str[1]

# %%
data
# Out:
#                Player year_period  Mat  Inns  Not_Out  Runs highest_score  \
# 0    DG Bradman (AUS)   1928-1948   52    80     10.0  6996           334
# 1      AC Voges (AUS)   2015-2016   20    31      7.0  1485          269*
# 2     RG Pollock (SA)   1963-1970   23    41      4.0  2256           274
# 3     GA Headley (WI)   1930-1954   22    40      4.0  2190          270*
# 4   H Sutcliffe (ENG)   1924-1935   54    84      9.0  4555           194
# ..                ...         ...  ...   ...      ...   ...           ...
# 57   KD Walters (AUS)   1965-1981   74   125     14.0  5357           250
# 58  GC Smith (ICC/SA)   2002-2014  117   205     13.0  9265           277
# 59  WH Ponsford (AUS)   1924-1934   29    48      4.0  2122           266
# 60    SJ McCabe (AUS)   1930-1938   39    62      5.0  2748           232
# 61   DR Jardine (ENG)   1928-1934   22    33      6.0  1296           127
#
#       Ave Ball_Faced  Strike_Rate  100  50   0    4s  6s  country
# ...

# %%
data['players'] = data['Player'].str.split(pat = '\(').str[0]

# %%
data
# Out:
#                Player year_period  Mat  Inns  Not_Out  Runs highest_score  \
# 0    DG Bradman (AUS)   1928-1948   52    80     10.0  6996           334
# 1      AC Voges (AUS)   2015-2016   20    31      7.0  1485          269*
# 2     RG Pollock (SA)   1963-1970   23    41      4.0  2256           274
# 3     GA Headley (WI)   1930-1954   22    40      4.0  2190          270*
# 4   H Sutcliffe (ENG)   1924-1935   54    84      9.0  4555           194
# ..                ...         ...  ...   ...      ...   ...           ...
# 57   KD Walters (AUS)   1965-1981   74   125     14.0  5357           250
# 58  GC Smith (ICC/SA)   2002-2014  117   205     13.0  9265           277
# 59  WH Ponsford (AUS)   1924-1934   29    48      4.0  2122           266
# 60    SJ McCabe (AUS)   1930-1938   39    62      5.0  2748           232
# 61   DR Jardine (ENG)   1928-1934   22    33      6.0  1296           127
#
#       Ave Ball_Faced  Strike_Rate  100  50   0    4s  6s  country  \
# ...

# %% [markdown]
# **droping the null coulmns**

# %%
data.drop(columns=['Player'], inplace=True)

# %%
data
# Out:
#    year_period  Mat  Inns  Not_Out  Runs highest_score    Ave Ball_Faced  \
# 0    1928-1948   52    80     10.0  6996           334  99.94      9800+
# 1    2015-2016   20    31      7.0  1485          269*  61.87       2667
# 2    1963-1970   23    41      4.0  2256           274  60.97      1707+
# 3    1930-1954   22    40      4.0  2190          270*  60.83       416+
# 4    1924-1935   54    84      9.0  4555           194  60.73      6558+
# ..         ...  ...   ...      ...   ...           ...    ...        ...
# 57   1965-1981   74   125     14.0  5357           250  48.26      8662+
# 58   2002-2014  117   205     13.0  9265           277  48.25      15525
# 59   1924-1934   29    48      4.0  2122           266  48.22      3118+
# 60   1930-1938   39    62      5.0  2748           232  48.21      3217+
# 61   1928-1934   22    33      6.0  1296           127  48.00      2110+
#
#     Strike_Rate  100  50   0    4s  6s  country       players
# ...

# %%
data['highest_score'] = data['highest_score'].str.split(pat = '*').str[0]

# %%
data['highest_score'].astype(int)
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 4     194
#      ...
# 57    250
# 58    277
# 59    266
# 60    232
# 61    127
# Name: highest_score, Length: 62, dtype: int64

# %%
data
# Out:
#    year_period  Mat  Inns  Not_Out  Runs highest_score    Ave Ball_Faced  \
# 0    1928-1948   52    80     10.0  6996           334  99.94      9800+
# 1    2015-2016   20    31      7.0  1485           269  61.87       2667
# 2    1963-1970   23    41      4.0  2256           274  60.97      1707+
# 3    1930-1954   22    40      4.0  2190           270  60.83       416+
# 4    1924-1935   54    84      9.0  4555           194  60.73      6558+
# ..         ...  ...   ...      ...   ...           ...    ...        ...
# 57   1965-1981   74   125     14.0  5357           250  48.26      8662+
# 58   2002-2014  117   205     13.0  9265           277  48.25      15525
# 59   1924-1934   29    48      4.0  2122           266  48.22      3118+
# 60   1930-1938   39    62      5.0  2748           232  48.21      3217+
# 61   1928-1934   22    33      6.0  1296           127  48.00      2110+
#
#     Strike_Rate  100  50   0    4s  6s  country       players
# ...

# %% [markdown]
# # **Making two new columns out of one cloumn**

# %%
data['start_year'] = data['year_period'].str.split(pat = '-').str[0]

# %%
data['end_year'] = data['year_period'].str.split(pat = '-').str[1]

# %%
data
# Out:
#    year_period  Mat  Inns  Not_Out  Runs highest_score    Ave Ball_Faced  \
# 0    1928-1948   52    80     10.0  6996           334  99.94      9800+
# 1    2015-2016   20    31      7.0  1485           269  61.87       2667
# 2    1963-1970   23    41      4.0  2256           274  60.97      1707+
# 3    1930-1954   22    40      4.0  2190           270  60.83       416+
# 4    1924-1935   54    84      9.0  4555           194  60.73      6558+
# ..         ...  ...   ...      ...   ...           ...    ...        ...
# 57   1965-1981   74   125     14.0  5357           250  48.26      8662+
# 58   2002-2014  117   205     13.0  9265           277  48.25      15525
# 59   1924-1934   29    48      4.0  2122           266  48.22      3118+
# 60   1930-1938   39    62      5.0  2748           232  48.21      3217+
# 61   1928-1934   22    33      6.0  1296           127  48.00      2110+
#
#     Strike_Rate  100  50   0    4s  6s  country       players start_year  \
# ...

# %%
data.drop(columns=['year_period'], inplace=True)

# %%
data
# Out:
#     Mat  Inns  Not_Out  Runs highest_score    Ave Ball_Faced  Strike_Rate  \
# 0    52    80     10.0  6996           334  99.94      9800+        58.60
# 1    20    31      7.0  1485           269  61.87       2667        55.68
# 2    23    41      4.0  2256           274  60.97      1707+        54.48
# 3    22    40      4.0  2190           270  60.83       416+        56.00
# 4    54    84      9.0  4555           194  60.73      6558+        34.59
# ..  ...   ...      ...   ...           ...    ...        ...          ...
# 57   74   125     14.0  5357           250  48.26      8662+        49.16
# 58  117   205     13.0  9265           277  48.25      15525        59.67
# 59   29    48      4.0  2122           266  48.22      3118+        44.77
# 60   39    62      5.0  2748           232  48.21      3217+        60.02
# 61   22    33      6.0  1296           127  48.00      2110+        25.59
#
#     100  50   0    4s  6s  country       players start_year end_year
# ...

# %% [markdown]
# **looking for data type**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Mat            62 non-null     int64
#  1   Inns           62 non-null     int64
#  2   Not_Out        62 non-null     float64
#  3   Runs           62 non-null     int64
#  4   highest_score  62 non-null     object
#  5   Ave            62 non-null     float64
#  6   Ball_Faced     62 non-null     object
#  7   Strike_Rate    62 non-null     float64
#  8   100            62 non-null     int64
#  9   50             62 non-null     int64
#  10  0              62 non-null     int64
#  11  4s             62 non-null     int64
#  12  6s             62 non-null     int64
#  13  country        62 non-null     object
#  14  players        62 non-null     object
#  15  start_year     62 non-null     object
#  16  end_year       62 non-null     object
# dtypes: float64(3), int64(8), object(6)
# ...

# %% [markdown]
# # **Correcting data type**

# %%
data['highest_score'] = data['highest_score'].astype(int)

# %%
data['end_year'] = data['end_year'].astype(int)

# %%
data['start_year'] = data['start_year'].astype(int)

# %%
data
# Out:
#     Mat  Inns  Not_Out  Runs  highest_score    Ave Ball_Faced  Strike_Rate  \
# 0    52    80     10.0  6996            334  99.94      9800+        58.60
# 1    20    31      7.0  1485            269  61.87       2667        55.68
# 2    23    41      4.0  2256            274  60.97      1707+        54.48
# 3    22    40      4.0  2190            270  60.83       416+        56.00
# 4    54    84      9.0  4555            194  60.73      6558+        34.59
# ..  ...   ...      ...   ...            ...    ...        ...          ...
# 57   74   125     14.0  5357            250  48.26      8662+        49.16
# 58  117   205     13.0  9265            277  48.25      15525        59.67
# 59   29    48      4.0  2122            266  48.22      3118+        44.77
# 60   39    62      5.0  2748            232  48.21      3217+        60.02
# 61   22    33      6.0  1296            127  48.00      2110+        25.59
#
# ...

# %%
# Replace non-digit characters and convert to integer
data['Ball_Faced'] = data['Ball_Faced'].str.split(pat = '+').str[0]

# %%
data['Ball_Faced']
# Out:
# 0      9800
# 1      2667
# 2      1707
# 3       416
# 4      6558
#       ...
# 57     8662
# 58    15525
# 59     3118
# 60     3217
# 61     2110
# Name: Ball_Faced, Length: 62, dtype: object

# %%
data['Ball_Faced'] = data['Ball_Faced'].replace('-', 0).astype('int')

# %%
data['Ball_Faced']
# Out:
# 0      9800
# 1      2667
# 2      1707
# 3       416
# 4      6558
#       ...
# 57     8662
# 58    15525
# 59     3118
# 60     3217
# 61     2110
# Name: Ball_Faced, Length: 62, dtype: int64

# %%
data
# Out:
#     Mat  Inns  Not_Out  Runs  highest_score    Ave  Ball_Faced  Strike_Rate  \
# 0    52    80     10.0  6996            334  99.94        9800        58.60
# 1    20    31      7.0  1485            269  61.87        2667        55.68
# 2    23    41      4.0  2256            274  60.97        1707        54.48
# 3    22    40      4.0  2190            270  60.83         416        56.00
# 4    54    84      9.0  4555            194  60.73        6558        34.59
# ..  ...   ...      ...   ...            ...    ...         ...          ...
# 57   74   125     14.0  5357            250  48.26        8662        49.16
# 58  117   205     13.0  9265            277  48.25       15525        59.67
# 59   29    48      4.0  2122            266  48.22        3118        44.77
# 60   39    62      5.0  2748            232  48.21        3217        60.02
# 61   22    33      6.0  1296            127  48.00        2110        25.59
#
# ...
